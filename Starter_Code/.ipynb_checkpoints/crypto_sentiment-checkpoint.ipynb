# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv("news_api")

# %%
from newsapi import NewsApiClient
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_headlines = newsapi.get_everything(
    q="Bitcoin",
    language="en"
)

# Print total articles
print(f"Total articles about Bitcoin: {bitcoin_headlines['totalResults']}")
# Out:
# Total articles about Bitcoin: 5228

# %%
# Fetch the Ethereum news articles
ethereum_headlines = newsapi.get_everything(
    q="Ethereum",
    language="en"
)

# Print total articles
print(f"Total articles about Ethereum: {ethereum_headlines['totalResults']}")
# Out:
# Total articles about Ethereum: 1325

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reorder DataFrame columns
cols = ["compound", "negative", "neutral","positive","text"]
bitcoin_df = bitcoin_df[cols]

bitcoin_df.head()
# Out:
#    compound  negative  neutral  positive  \
# 0    0.6369     0.000    0.838     0.162
# 1    0.6486     0.000    0.826     0.174
# 2    0.4019     0.000    0.928     0.072
# 3    0.2732     0.083    0.781     0.136
# 4   -0.2924     0.059    0.941     0.000
#
#                                                 text
# 0  Visa has partnered with cryptocurrency startup...
# 1  After reaching a previous all-time high on Nov...
# 2  Its been almost three years to the day since t...
# 3  Everything is dumb until it works.\r\nAs 2020 ...
# 4  The government of India is considering an 18% ...

# %%
# Create the ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["compound", "negative", "neutral","positive","text"]
ethereum_df = ethereum_df[cols]

ethereum_df.head()
# Out:
#    compound  negative  neutral  positive  \
# 0    0.5267     0.000    0.864     0.136
# 1    0.0772     0.085    0.849     0.066
# 2    0.0000     0.000    1.000     0.000
# 3    0.0000     0.000    1.000     0.000
# 4    0.0000     0.000    1.000     0.000
#
#                                                 text
# 0  The Securities and Exchange Commission plans t...
# 1  Bitcoin was once derided by serious investors ...
# 2  FILE PHOTO: A representation of virtual curren...
# 3  FILE PHOTO: Representations of virtual currenc...
# 4  FILE PHOTO: Representations of virtual currenc...

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#         compound   negative    neutral   positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.278550   0.015900   0.899100   0.084950
# std     0.377834   0.033444   0.074112   0.073759
# min    -0.585900   0.000000   0.781000   0.000000
# 25%     0.000000   0.000000   0.846250   0.000000
# 50%     0.337550   0.000000   0.890000   0.086500
# 75%     0.636900   0.000000   0.962500   0.148750
# max     0.801600   0.103000   1.000000   0.209000

# %%
# Describe the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         compound   negative    neutral   positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.135540   0.015450   0.935100   0.049450
# std     0.284275   0.032516   0.066441   0.058508
# min    -0.493900   0.000000   0.797000   0.000000
# 25%     0.000000   0.000000   0.878250   0.000000
# 50%     0.038600   0.000000   0.944500   0.026000
# 75%     0.286575   0.000000   1.000000   0.080250
# max     0.636900   0.099000   1.000000   0.155000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
import nltk
nltk.download('stopwords')
# Expand the default stopwords list if necessary
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dmksk\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Complete the tokenizer function
def tokenizer(article):
    """Tokenizes text."""
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('',str(article))
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    tokens = [word.lower() for word in lem if word.lower() not in sw]
   
    return tokens

# %%
# Create a new tokens column for bitcoin
bitcoin_df["tokens"] = bitcoin_df.text.apply(tokenizer)
bitcoin_df.head()
# Out:
#    compound  negative  neutral  positive  \
# 0    0.6369     0.000    0.838     0.162
# 1    0.6486     0.000    0.826     0.174
# 2    0.4019     0.000    0.928     0.072
# 3    0.2732     0.083    0.781     0.136
# 4   -0.2924     0.059    0.941     0.000
#
#                                                 text  \
# 0  Visa has partnered with cryptocurrency startup...
# 1  After reaching a previous all-time high on Nov...
# 2  Its been almost three years to the day since t...
# 3  Everything is dumb until it works.\r\nAs 2020 ...
# 4  The government of India is considering an 18% ...
#
#                                               tokens
# 0  [visahas, partnered, cryptocurrency, startup, ...
# 1  [reaching, previous, alltime, high, november, ...
# 2  [almost, three, year, day, since, price, bitco...
# 3  [everything, dumb, worksas, come, close, crypt...
# 4  [government, india, considering, tax, bitcoin,...

# %%
# Create a new tokens column for ethereum
ethereum_df["tokens"] = ethereum_df.text.apply(tokenizer)
ethereum_df.head()
# Out:
#    compound  negative  neutral  positive  \
# 0    0.5267     0.000    0.864     0.136
# 1    0.0772     0.085    0.849     0.066
# 2    0.0000     0.000    1.000     0.000
# 3    0.0000     0.000    1.000     0.000
# 4    0.0000     0.000    1.000     0.000
#
#                                                 text  \
# 0  The Securities and Exchange Commission plans t...
# 1  Bitcoin was once derided by serious investors ...
# 2  FILE PHOTO: A representation of virtual curren...
# 3  FILE PHOTO: Representations of virtual currenc...
# 4  FILE PHOTO: Representations of virtual currenc...
#
#                                               tokens
# 0  [securities, exchange, commission, plan, sue, ...
# 1  [bitcoin, wa, derided, serious, investor, bubb...
# 2  [file, photo, representation, virtual, currenc...
# 3  [file, photo, representations, virtual, curren...
# 4  [file, photo, representations, virtual, curren...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
processed_bitcoin = tokenizer(bitcoin_df["tokens"])
bitcoin_counts = Counter(ngrams(processed_bitcoin, n=2))
biggrams_bitcoin = (dict(bitcoin_counts))
biggrams_bitcoin
# Out:
# {('visahas', 'partnered'): 1,
#  ('partnered', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'startup'): 1,
#  ('startup', 'reaching'): 1,
#  ('reaching', 'previous'): 1,
#  ('previous', 'alltime'): 1,
#  ('alltime', 'high'): 1,
#  ('high', 'november'): 1,
#  ('november', 'almost'): 1,
#  ('almost', 'three'): 1,
#  ('three', 'year'): 1,
#  ('year', 'day'): 1,
#  ('day', 'since'): 1,
#  ('since', 'price'): 1,
#  ('price', 'bitco'): 1,
#  ('bitco', 'everything'): 1,
#  ('everything', 'dumb'): 1,
#  ('dumb', 'worksas'): 1,
#  ('worksas', 'come'): 1,
#  ('come', 'close'): 1,
#  ('close', 'crypt'): 1,
#  ('crypt', 'government'): 1,
#  ('government', 'india'): 1,
#  ('india', 'considering'): 1,
#  ('considering', 'tax'): 1,
#  ('tax', 'bitcoin'): 1,
#  ('bitcoin', 'security'): 1,
#  ('security', 'exchange'): 1,
#  ('exchange', 'commission'): 1,
#  ('commission', 'plan'): 1,
#  ('plan', 'sue'): 1,
#  ('sue', 'unlike'): 1,
#  ('unlike', 'conventional'): 1,
# ...

# %%
# Generate the Ethereum N-grams where N=2
processed_ethereum = tokenizer(ethereum_df["tokens"])
ethereum_counts = Counter(ngrams(processed_ethereum, n=2))
biggrams_ethereum = (dict(bitcoin_counts))
biggrams_ethereum
# Out:
# {('visahas', 'partnered'): 1,
#  ('partnered', 'cryptocurrency'): 1,
#  ('cryptocurrency', 'startup'): 1,
#  ('startup', 'reaching'): 1,
#  ('reaching', 'previous'): 1,
#  ('previous', 'alltime'): 1,
#  ('alltime', 'high'): 1,
#  ('high', 'november'): 1,
#  ('november', 'almost'): 1,
#  ('almost', 'three'): 1,
#  ('three', 'year'): 1,
#  ('year', 'day'): 1,
#  ('day', 'since'): 1,
#  ('since', 'price'): 1,
#  ('price', 'bitco'): 1,
#  ('bitco', 'everything'): 1,
#  ('everything', 'dumb'): 1,
#  ('dumb', 'worksas'): 1,
#  ('worksas', 'come'): 1,
#  ('come', 'close'): 1,
#  ('close', 'crypt'): 1,
#  ('crypt', 'government'): 1,
#  ('government', 'india'): 1,
#  ('india', 'considering'): 1,
#  ('considering', 'tax'): 1,
#  ('tax', 'bitcoin'): 1,
#  ('bitcoin', 'security'): 1,
#  ('security', 'exchange'): 1,
#  ('exchange', 'commission'): 1,
#  ('commission', 'plan'): 1,
#  ('plan', 'sue'): 1,
#  ('sue', 'unlike'): 1,
#  ('unlike', 'conventional'): 1,
# ...

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
bitcoin_token = tokenizer(bitcoin_df.text.str.cat())
bitcoin_10 = token_count(bitcoin_token)
bitcoin_10
# Out:
# [('bitcoin', 13),
#  ('reuters', 9),
#  ('cryptocurrency', 7),
#  ('ha', 7),
#  ('year', 6),
#  ('alltime', 4),
#  ('november', 4),
#  ('wa', 4),
#  ('new', 4),
#  ('charsby', 4)]

# %%
# Get the top 10 words for Ethereum
ethereum_token = tokenizer(ethereum_df.text.str.cat())
ethereum_10 = token_count(ethereum_token)
ethereum_10
# Out:
# [('bitcoin', 14),
#  ('reuters', 14),
#  ('currency', 9),
#  ('us', 9),
#  ('cryptocurrency', 8),
#  ('taken', 8),
#  ('fund', 7),
#  ('photo', 6),
#  ('virtual', 6),
#  ('illustration', 6)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
wordcloud = WordCloud().generate(bitcoin_df.text.str.cat())
plt.imshow(wordcloud)
fontdict = {"fontsize": 50, "fontweight": "bold"}
plt.title("Bitcoin Word Cloud", fontdict=fontdict)
plt.show()

# %%
# Generate the Bitcoin word cloud
bitcoin_wc = WordCloud().generate(bitcoin_df.text.str.cat())
plt.imshow(bitcoin_wc)
plt.title("Bitcoin Word Cloud", fontsize=60, fontstyle='normal')
plt.show()

# %%
# Generate the Ethereum word cloud
ethereum_wc = WordCloud().generate(ethereum_df.text.str.cat())
plt.imshow(ethereum_wc)
plt.title("Ethereum Word Cloud", fontsize=60, fontstyle='normal')
plt.show()

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
concat_bitcoin = bitcoin_df.text.str.cat()

# %%
# Run the NER processor on all of the text
processed_bitcoin = nlp(concat_bitcoin)

# Add a title to the document
processed_bitcoin.user_data['title'] = 'Bitcoin NER'

# %%
# Render the visualization
displacy.render(processed_bitcoin, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Visa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has partnered with cryptocurrency startup BlockFi to offer the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  rewards credit card that pays out in
# ...

# %%
# List all Entities
for word in processed_bitcoin.ents:
    print(word.text, word.label_)
# Out:
# Visa ORG
# first ORDINAL
# Bitcoin GPE
# November 30th, 2020 DATE
# December 1st DATE
# 2020 DATE
# bitcoin GPE
# above $20,000 MONEY
# almost three years DATE
# the day DATE
# Bitcoin GPE
# 20,000 MONEY
# Wednesday DATE
# 2020 DATE
# late-year DATE
# Bitcoin GPE
# over $23,000 MONEY
# India GPE
# 18% PERCENT
# bitcoin GPE
# the Times of India ORG
# chars]The Securities and Exchange Commission ORG
# digital yuan ORG
# the People’s Bank of China ORG
# Bitcoin GPE
# 20,000 MONEY
# 14,800 MONEY
# more than 170% PERCENT
# this year DATE
# chars]Six years DATE
# Mexico GPE
# $62 million MONEY
# chars]4 CARDINAL
# U.S. GPE
# November DATE
# today DATE
# 500 CARDINAL
# 10.8 percent PERCENT
# November DATE
# monthly DATE
# April DATE
# fourth ORDINAL
# Grayson Blackmon / PERSON
# One CARDINAL
# the year DATE
# the day DATE
# Twitter ORG
# chars]6 CARDINAL
# 6 CARDINAL
# one CARDINAL
# above $20,000 MONEY
# Wednesday DATE
# a year DATE
# Reuters ORG
# Bitcoin GPE
# U.S. GPE
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the bitcoin text together
concat_ethereum = ethereum_df.text.str.cat()

# %%
# Run the NER processor on all of the text
processed_ethereum = nlp(concat_ethereum)

# Add a title to the document
processed_ethereum.user_data['title'] = 'Ethereum NER'

# %%
# Render the visualization
displacy.render(processed_ethereum, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Securities and Exchange Commission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  plans to sue Ripple in federal civil court for selling unregistered securities, according to a news release published online by the cryptocurrency company late … [+2950 chars]Bitcoin was once derided by serious investors as a bubble or a Ponzi scheme. But
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
# ...

# %%
# List all Entities
for word in processed_ethereum.ents:
    print(word.text, word.label_)
# Out:
# The Securities and Exchange Commission ORG
# this year DATE
# Wednesday DATE
# bitcoin GPE
# 20,000 MONEY
# Bitcoin GPE
# November 19, 2020 DATE
# REUTERS/ ORG
# Reuters ORG
# U.S. GPE
# Bitcoin GPE
# March 13, 2020 DATE
# REUTERS/ ORG
# Reuters ORG
# U.S. GPE
# Bitcoin GPE
# March 13, 2020 DATE
# REUTERS/ ORG
# Reuters ORG
# U.S. GPE
# YORK PERSON
# Reuters ORG
# $429 million MONEY
# the week ended Dec. 7 DATE
# second ORDINAL
# YORK PERSON
# Reuters ORG
# $429 million MONEY
# the week ended Dec. 7 DATE
# second ORDINAL
# YORK PERSON
# Reuters ORG
# $5.6 billion MONEY
# this year DATE
# more than 600% PERCENT
# 2019 DATE
# Coin ORG
# 15, 2020 DATE
# 6 min QUANTITY
# A few days ago DATE
# US GPE
# Cynthia Lummis PERSON
# Bitcoin GPE
# second ORDINAL
# December 2020 DATE
# first ORDINAL
# Ethereum 2.0 ORG
# YORK PERSON
# Reuters ORG
# U.S. GPE
# the years DATE
# U.S. GPE
# Reuters ORG
# Bitcoin GPE
# U.S. GPE
# May 26, 2020 DATE
# REUTERS/ ORG
# Reuters ORG
# Reuters ORG
# ...
